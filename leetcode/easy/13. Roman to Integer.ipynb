# %%
class Solution:
    def romanToInt(self, s: str) -> int:
        dictionary =  {'I': 1,
                    'V': 5,
                    'X': 10,
                    'L': 50,
                    'C': 100,
                    'D': 500,
                    'M': 1000  
        }
        last, next = 0,0
        word = ''
        date = 0
        while next < len(s):
            next += 1
            word += s[last]
            print(dictionary[s[next]])
            if dictionary[s[last]] > dictionary[s[next]] and next <= len(s):
                word += s[next]
                if word in ('IV','IX','LX','CX','CD','CM'):
                    last = next
                    word = list(word)
                    date += max(dictionary[word[0]], dictionary[word[1]]) - min(dictionary[word[0]], dictionary[word[1]])
                else:
                    last = next
                    print(dictionary[s[next]])
                    date += dictionary[s[next]]

sol = Solution()
sol.romanToInt('XVI')
# Out:
# 5
# 5
# 1
# 1
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 30
#      27                     date += dictionary[s[next]]
#      29 sol = Solution()
# ---> 30 sol.romanToInt('XVI')
#
# Cell In[3], line 17, in Solution.romanToInt(self, s)
#      15 next += 1
#      16 word += s[last]
# ---> 17 print(dictionary[s[next]])
#      18 if dictionary[s[last]] > dictionary[s[next]] and next <= len(s):
#      19     word += s[next]
#
# IndexError: string index out of range

# %%
class Solution:
    def romanToInt(self, s: str) -> int:
        dictionary =  {'I': 1,
                    'V': 5,
                    'X': 10,
                    'L': 50,
                    'C': 100,
                    'D': 500,
                    'M': 1000  
        }
        year = 0
        for i in range(len(s), -1, -1, -1):
            year += dictionary[i]
